# %% [markdown]
# # Environment setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/shimnet_workshop
# !pip uninstall -y torchtune
# !pip install -r requirements-colab.txt
# !python download_files.py --all --overwrite

# %% [markdown]
# # ShimNet predict - training on singlets

# %%
#------------SET INPUT (DISTORTED SPECTRUM)-------------
input_spectrum_name="Asarone_reduce_volume"                   #change model to shimnet_600MHz.pt shimnet_600.yaml
#input_spectrum_name="lineshape_deshimmed"                     #change model to shimnet_700MHz.pt shimnet_700.yaml
#input_spectrum_name ="styrene_1mm_600MHz_deshimmed"          #change model to shimnet_600MHz.pt shimnet_600.yaml
#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_singlets_600MHz.pt'
config_file  = './configs/shimnet_singlets_600.yaml'
#--------------------------------------------------
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'


# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    --suffix "_only_singlets" \
     {input_csv}

#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_600MHz.pt'
config_file  = './configs/shimnet_600.yaml'

#--------------------------------------------------
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'


# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    --suffix "_published_model" \
{input_csv}

# %% [markdown]
# # Plot results - training on singlets

# %%
from display_spectra import display_spectra

#------------SET INPUT -------------
input_spectrum_name="Asarone_reduce_volume"
input_opti_spectrum_name = "Asarone"

#input_spectrum_name="lineshape_deshimmed"
#input_opti_spectrum_name = "lineshape"

#input_spectrum_name="styrene_1mm_600MHz_deshimmed"
#input_opti_spectrum_name = "styrene_600MHz"

#--------------------------------------------------

input_spectrum_file = "./INPUT/"+input_spectrum_name+".csv"
corrected_spectrum_file = "./OUTPUT/"+input_spectrum_name+"_only_singlets.csv"
corrected_spectrum_file2 = "./OUTPUT/"+input_spectrum_name+"_published_model.csv"
reference_spectrum_file = "./OPTI_INPUT_SPECTRA/"+input_opti_spectrum_name+"_shimmed.csv"

display_spectra(input_spectrum_file, corrected_spectrum_file, corrected_file2=corrected_spectrum_file2, reference_file=reference_spectrum_file)

# %% [markdown]
# # ShimNet predict - training on various dynamic ranges

# %%
#------------SET INPUT (DISTORTED SPECTRUM)-------------
input_spectrum_name="Cresol_Red_600MHz_after_different_sample"                   #change model to shimnet_600MHz.pt shimnet_600.yaml
#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_600MHz.pt'
config_file  = './configs/shimnet_600.yaml'
#--------------------------------------------------
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'


# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    --suffix "_published_model" \
     {input_csv}

#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_600_wide-hm_constant-hs.pt'
config_file  = './configs/shimnet_600_wide-hm_constant-hs.yaml'
#--------------------------------------------------
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'


# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    --suffix "_narrow_abs" \
{input_csv}

#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_600_wide-hm_standard-hs.pt'
config_file  = './configs/shimnet_600_wide-hm_standard-hs.yaml'
#--------------------------------------------------
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'


# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    --suffix "_standard_abs" \
{input_csv}

# %% [markdown]
# # Plot results - training on various dynamic ranges

# %%
from display_spectra import display_spectra

#------------SET INPUT -------------
input_spectrum_name="Cresol_Red_600MHz_after_different_sample"
input_opti_spectrum_name = "Cresol_Red_600MHz"
#--------------------------------------------------

input_spectrum_file = "./INPUT/"+input_spectrum_name+".csv"
corrected_spectrum_file = "./OUTPUT/"+input_spectrum_name+"_standard_abs.csv"
corrected_spectrum_file2 = "./OUTPUT/"+input_spectrum_name+"_published_model.csv"
reference_spectrum_file = "./OPTI_INPUT_SPECTRA/"+input_opti_spectrum_name+"_shimmed.csv"

display_spectra(input_spectrum_file, corrected_spectrum_file, corrected_file2=corrected_spectrum_file2, reference_file=reference_spectrum_file)
