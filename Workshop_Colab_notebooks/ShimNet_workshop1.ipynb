# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone -b workshops https://github.com/center4ml/shimnet.git

# !cp -r shimnet /content/drive/MyDrive/shimnet_workshop
# %cd /content/drive/MyDrive/shimnet_workshop
# Out:
# fatal: destination path 'shimnet' already exists and is not an empty directory.
# /content/drive/MyDrive/shimnet_workshop

# %%
# !pip uninstall torchtune
# !pip install -r requirements-colab.txt
# Out:
# WARNING: Skipping torchtune as it is not installed.
# Requirement already satisfied: nmrglue==0.11 in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 1)) (0.11)
# Requirement already satisfied: torchdata==0.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 2)) (0.9.0)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 3)) (1.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from nmrglue==0.11->-r requirements-colab.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from nmrglue==0.11->-r requirements-colab.txt (line 1)) (1.16.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.12/dist-packages (from torchdata==0.9.0->-r requirements-colab.txt (line 2)) (2.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torchdata==0.9.0->-r requirements-colab.txt (line 2)) (2.32.4)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.12/dist-packages (from torchdata==0.9.0->-r requirements-colab.txt (line 2)) (2.8.0+cu126)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core->-r requirements-colab.txt (line 3)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->-r requirements-colab.txt (line 3)) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core->-r requirements-colab.txt (line 3)) (25.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf<2.4,>=2.2->hydra-core->-r requirements-colab.txt (line 3)) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2->torchdata==0.9.0->-r requirements-colab.txt (line 2)) (3.0.2)

# %%
# !pip install -r requirements-gpu.txt
# !python download_files.py --all --overwrite
# Out:
# File /content/drive/MyDrive/shimnet_workshop/weights/shimnet_700MHz.pt already exists. Overwrite? (y/n): n
# Download of /content/drive/MyDrive/shimnet_workshop/weights/shimnet_700MHz.pt cancelled
# File /content/drive/MyDrive/shimnet_workshop/weights/shimnet_600MHz.pt already exists. Overwrite? (y/n): n
# Download of /content/drive/MyDrive/shimnet_workshop/weights/shimnet_600MHz.pt cancelled
# File /content/drive/MyDrive/shimnet_workshop/data/scrf_61_700MHz.pt already exists. Overwrite? (y/n): n
# Download of /content/drive/MyDrive/shimnet_workshop/data/scrf_61_700MHz.pt cancelled
# File /content/drive/MyDrive/shimnet_workshop/data/scrf_81_600MHz.pt already exists. Overwrite? (y/n): n
# Download of /content/drive/MyDrive/shimnet_workshop/data/scrf_81_600MHz.pt cancelled
# File /content/drive/MyDrive/shimnet_workshop/data/multiplets_10000_parsed.txt already exists. Overwrite? (y/n): n
# Download of /content/drive/MyDrive/shimnet_workshop/data/multiplets_10000_parsed.txt cancelled

# %%
from google.colab import drive
import os
from zipfile import ZipFile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import output
output.enable_custom_widget_manager()

# %%
#input_spectrum_name="Asarone_deshimmed"
#input_spectrum_name="Asarone_reduce_volume"
#input_spectrum_name="lineshape_deshimmed"
input_spectrum_name="Cresol_Red_after_different_sample_cut"
#input_spectrum_name="Cresol_Red_after_different_sample"
#input_spectrum_name="multi_singlets_deshimmed"

input_csv = "./INPUT/"+input_spectrum_name+".csv"

weights_file = './weights/shimnet_600MHz.pt'
config_file  = './configs/shimnet_600.yaml'

output_dir = './OUTPUT/'

##Uruchomienie programu##
# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    {input_csv}
# Out:
# processing ./INPUT/Cresol_Red_after_different_sample_cut.csv ...
# saved to OUTPUT/Cresol_Red_after_different_sample_cut_processed.csv

# %%
from display_spectra import run

import os
from pathlib import Path

# każdy plik CSV powinien mieć 2 kolumny: [freq, intensity]
#input_spectrum_name="Asarone_deshimmed"
#input_opti_spectrum_name = "Asarone"

#input_spectrum_name="Asarone_reduce_volume"
#input_opti_spectrum_name = "Asarone"

#input_spectrum_name="lineshape_deshimmed"
#input_opti_spectrum_name = "lineshape"

input_spectrum_name="Cresol_Red_after_different_sample_cut"
input_opti_spectrum_name = "Cresol_Red_cut"

#input_spectrum_name="multi_singlets_deshimmed"
#input_opti_spectrum_name = "multi_singlets"

input_spectrum_file = "./INPUT/"+input_spectrum_name+".csv"
corrected_spectrum_file = "./OUTPUT/"+input_spectrum_name+"_processed.csv"
reference_spectrum_file = "./OPTI_INPUT_SPECTRA/"+input_opti_spectrum_name+"_shimmed.csv"
# create output directory:
Path(corrected_spectrum_file).parent.mkdir(parents=True, exist_ok=True)


os.environ["INPUT_SPECTRUM_FILE"] = input_spectrum_file
os.environ["CORRECTED_SPECTRUM_FILE"] = corrected_spectrum_file or ""
os.environ["REFERENCE_SPECTRUM_FILE"] = reference_spectrum_file or ""

run(input_spectrum_file, corrected_spectrum_file, reference_spectrum_file)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d6305d2b-c620-4f6d-b0e0-38625f2150ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6305d2b-c620-4f6d-b0e0-38625f2150ff")) {                    Plotly.newPlot(                        "d6305d2b-c620-4f6d-b0e0-38625f2150ff",                        [{"line":{"color":"#EF553B"},"mode":"lines","name":"Input Spectrum","x":[-2.01478,-2.01453,-2.01429,-2.01404,-2.0138,-2.01356,-2.01331,-2.01307,-2.01282,-2.01258,-2.01233,-2.01209,-2.01184,-2.0116,-2.01135,-2.01111,-2.01087,-2.01062,-2.01038,-2.01013,-2.00989,-2.00964,-2.0094,-2.00915,-2.00891,-2.00866,-2.00842,-2.00817,-2.00793,-2.00769,-2.00744,-2.0072,-2.00695,-2.00671,-2.00646,-2.00622,-2.00597,-2.00573,-2.00548,-2.00524,-2.00499,-2.00475,-2.00451,-2.00426,-2.00402,-2.00377,-2.00353,-2.00328,-2.00304,-2.00279,-2.00255,-2.0023,-2.00206,-2.00181,-2.00157,-2.00133,-2.00108,-2.00084,-2.00059,-2.00035,-2.0001,-1.99986,-1.99961,-1.99937,-1.99912,-1.99888,-1.99863,-1.99839,-1.99815,-1.9979,-1.99766,-1.99741,-1.99717,-1.99692,-1.99668,-1.99643,-1.99619,-1.99594,-1.9957,-1.99546,-1.99521,-1.99497,-1.99472,-1.99448,-1.99423,-1.99399,-1.99374,-1.9935,-1.99325,-1.99301,-1.99276,-1.99252,-1.99228,-1.99203,-1.99179,-1.99154,-1.9913,-1.99105,-1.99081,-1.99056,-1.99032,-1.99007,-1.98983,-1.98958,-1.98934,-1.9891,-1.98885,-1.98861,-1.98836,-1.98812,-1.98787,-1.98763,-1.98738,-1.98714,-1.98689,-1