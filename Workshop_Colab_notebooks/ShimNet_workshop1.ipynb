# %% [markdown]
# # Environment setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/shimnet_workshop
# !pip uninstall -y torchtune
# !pip install -r requirements-colab.txt
# !python download_files.py --all --overwrite
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/shimnet_workshop
# Found existing installation: torchtune 0.6.1
# Uninstalling torchtune-0.6.1:
#   Successfully uninstalled torchtune-0.6.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.1/226.1 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 68.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 9.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchdata
#     Found existing installation: torchdata 0.11.0
#     Uninstalling torchdata-0.11.0:
#       Successfully uninstalled torchdata-0.11.0
# ...
# Downloaded /content/drive/MyDrive/shimnet_workshop/weights/shimnet_700MHz.pt
# Downloaded /content/drive/MyDrive/shimnet_workshop/weights/shimnet_600MHz.pt
# Downloaded /content/drive/MyDrive/shimnet_workshop/data/scrf_61_700MHz.pt
# Downloaded /content/drive/MyDrive/shimnet_workshop/data/scrf_81_600MHz.pt
# ...

# %% [markdown]
# # ShimNet predict

# %%
#------------SET INPUT (DISTORTED SPECTRUM)-------------
input_spectrum_name="Asarone_deshimmed"                       #change model to shimnet_600MHz.pt shimnet_600.yaml
#input_spectrum_name="Asarone_reduce_volume"                   #change model to shimnet_600MHz.pt shimnet_600.yaml
#input_spectrum_name="lineshape_deshimmed"                     #change model to shimnet_700MHz.pt shimnet_700.yaml
#input_spectrum_name="multi_singlets_deshimmed"                #change model to shimnet_700MHz.pt shimnet_700.yaml
#input_spectrum_name ="styrene_1mm_600MHz_deshimmed"          #change model to shimnet_600MHz.pt shimnet_600.yaml
#input_spectrum_name = "2etnaft_600MHz_deshimmed"             #change model to shimnet_600MHz.pt shimnet_600.yaml
#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_600MHz.pt'
config_file  = './configs/shimnet_600.yaml'

#weights_file = './weights/shimnet_700MHz.pt'
#config_file  = './configs/shimnet_700.yaml'
#--------------------------------------------------
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'


# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    {input_csv}

# %% [markdown]
# # Plot results

# %%
from display_spectra import display_spectra

#------------SET INPUT -------------
input_spectrum_name="Asarone_deshimmed"
input_opti_spectrum_name = "Asarone"

#input_spectrum_name="Asarone_reduce_volume"
#input_opti_spectrum_name = "Asarone"

#input_spectrum_name="lineshape_deshimmed"
#input_opti_spectrum_name = "lineshape"

#input_spectrum_name="multi_singlets_deshimmed"
#input_opti_spectrum_name = "multi_singlets"

#input_spectrum_name="2etnaft_600MHz_deshimmed"
#input_opti_spectrum_name = "2etnaft_600MHz"

#input_spectrum_name="styrene_1mm_600MHz_deshimmed"
#input_opti_spectrum_name = "styrene_600MHz"


#--------------------------------------------------

input_spectrum_file = "./INPUT/"+input_spectrum_name+".csv"
corrected_spectrum_file = "./OUTPUT/"+input_spectrum_name+"_processed.csv"
reference_spectrum_file = "./OPTI_INPUT_SPECTRA/"+input_opti_spectrum_name+"_shimmed.csv"

display_spectra(input_spectrum_file, corrected_spectrum_file, reference_file=reference_spectrum_file)

# %% [markdown]
# # ShimNet predict - high intensity range

# %%
#------------SET INPUT (DISTORTED SPECTRUM)-------------
input_spectrum_name="Cresol_Red_after_different_sample_cut"   #change model to shimnet_700MHz.pt shimnet_700.yaml
#-------------SET MODEL (WEIGHTS) AND CONFIG (PARAMETERS)-----------
weights_file = './weights/shimnet_700MHz.pt'
config_file  = './configs/shimnet_700.yaml'
#--------------------------------------------------

input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'

# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    {input_csv}

#------------SET INPUT (DISTORTED SPECTRUM)-------------
input_spectrum_name="Cresol_Red_after_different_sample"   #change model to shimnet_700MHz.pt shimnet_700.yaml
input_csv = "./INPUT/"+input_spectrum_name+".csv"
output_dir = './OUTPUT/'

# !python ./predict.py \
    --weights {weights_file} \
    --config {config_file} \
    -o {output_dir} \
    {input_csv}

# %% [markdown]
# # Plot results - high intensity range

# %%
input_spectrum_name="Cresol_Red_after_different_sample"
input_spectrum_name1="Cresol_Red_after_different_sample_cut"
input_spectrum_name2="Cresol_Red_after_different_sample"
input_opti_spectrum_name = "Cresol_Red"

input_spectrum_file = "./INPUT/"+input_spectrum_name+".csv"
corrected_spectrum_file1 = "./OUTPUT/"+input_spectrum_name1+"_processed.csv"
corrected_spectrum_file2 = "./OUTPUT/"+input_spectrum_name2+"_processed.csv"
reference_spectrum_file = "./OPTI_INPUT_SPECTRA/"+input_opti_spectrum_name+"_shimmed.csv"

display_spectra(input_spectrum_file, corrected_spectrum_file1, reference_file=reference_spectrum_file, corrected_file2=corrected_spectrum_file2)
